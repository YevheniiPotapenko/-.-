# %% [markdown]
# <a href="https://colab.research.google.com/github/YevheniiPotapenko/Files/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0_5_%D0%9F%D0%BE%D1%82%D0%B0%D0%BF%D0%B5%D0%BD%D0%BA%D0%B0_%D0%84%D0%B2%D0%B3%D0%B5%D0%BD%D0%B0_%D0%9E%D0%BB%D0%B5%D0%BA%D1%81%D0%B0%D0%BD%D0%B4%D1%80%D0%BE%D0%B2%D0%B8%D1%87%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Лабораторна робота 5, Потапенка Євгена Олександровича, Група ФІТ 2-15. Варіант 11.
# Тема: Розв'язання систем нелінійних рівнянь.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Область значень для x та y
x_min, x_max = -1, 1.2
y_min, y_max = -2, 2
step = 0.001

# Створюємо масиви  значень
x, y = np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))

# Рівняння системи
eq1 = np.sin(y + 1) - x - 1.2
eq2 = 2 * y + np.cos(x) - 2

# Створюємо графіка
fig, ax = plt.subplots(figsize=(8, 8))

#Додаємо графік першого рівняння
ax.contour(x, y, eq1, levels=[0], colors='red', linewidths=1.5)

# Додаємо графік другого рівняння
ax.contour(x, y, eq2, levels=[0], colors='blue', linewidths=1.5)

# Налаштування графіка
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Графік системи рівнянь')

# Додаємо стрілки на кінцях осей
ax.arrow(0, y_min, 0, y_max - y_min, head_width=0.02, head_length=0.1, fc='black', ec='black')
ax.arrow(x_min, 0, x_max - x_min, 0, head_width=0.02, head_length=0.1, fc='black', ec='black')

# Додаємо сітку
plt.grid(True)

#Показуємо графік
plt.show()

# %% [markdown]
# ![Знімок екрана 2025-05-18 223324.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
from scipy import optimize

# Початкові наближення
x0 = 0.15
y0 = -2.1

# Переписуємо систему у вигляді y = f(x), x = f(y)
def f1(y):
    return (np.sin(y - 0.5) + 1) / 2

def f2(x):
    return 1.5 - np.cos(x)

# Метод простої ітерації
def iter_method(x, y, e):
    xn = x
    yn = y
    n = 0
    while True:
        x1 = f1(yn)
        y1 = f2(xn)
        if max(abs(x1 - xn), abs(y1 - yn)) < e:
            break
        xn, yn = x1, y1
        n += 1
    print("Метод простої ітерації:")
    print(f"x = {xn}, y = {yn} \nКількість ітерацій = {n}")

iter_method(0.15, -2.1, 0.00001)

# Перевірка за допомогою scipy.optimize.root
def f3(x):  # Система рівнянь
    return [
        np.cos(x[0]) + x[1] - 1.5,
        2 * (np.sin(x[1] - 0.5) - 0.5) - x[0]
    ]

s = optimize.root(f3, [x0, y0], method='hybr')
print("Chek():", s.x)
# Out:
# Метод простої ітерації:
# x = 0.5819185469670914, y = 0.6645807482974894
# Кількість ітерацій = 16
# Chek(): [1.0138913  1.44165331]

# %% [markdown]
# Висновок: Виконавши  дану лабораторну роботу, я переглянув свій підхід до  розв'язання систем нелінійних рівнянь та прилизно зрозумів як їх розв'язувати
